# %%
import pandas as pd

# %%
df = pd.read_csv('database.csv', index_col=False)

# %%
display(df)
# Out:
#           prise  rooms  square  floor  totalFloors  flat/studio  \
# 0      650000.0    1.0    35.7      2            6          0.0
# 1     8655450.0    5.0   276.0     24           25          1.0
# 2      745000.0    1.0    15.3     16           24          0.0
# 3     4999000.0    3.0    88.7     24           27          1.0
# 4     4500000.0    4.0   127.0      4           32          1.0
# ...         ...    ...     ...    ...          ...          ...
# 4985  1399000.0    2.0    56.0     12           15          1.0
# 4986  4350000.0    3.0   105.0     10           32          1.0
# 4987  1350000.0    2.0    38.4      2           14          1.0
# 4988   295000.0    1.0    17.7      1            5          0.0
# 4989  1987000.0    1.0    42.0      9           16          1.0
#
#                          address  coordinate  distanceFromTheCenter  metro  \
# 0            Варшавское ш.,  125         NaN                    NaN    NaN
# 1             ул. Лавочкина,  34         NaN                    NaN    NaN
# 2           Ленинский пр-т,  158         NaN                    NaN    NaN
# 3      Шелепихинская наб.,  42к2         NaN                    NaN    NaN
# 4        пр-т Вернадского,  вл78         NaN                    NaN    NaN
# ...                          ...         ...                    ...    ...
# 4985    Скандинавский б-р,  23к2         NaN                    NaN    NaN
# 4986  1-й Нагатинский пр.,  11к2         NaN                    NaN    NaN
# 4987          Озёрная ул.,  29к1         NaN                    NaN    NaN
# 4988      ул. Орджоникидзе,  6/9         NaN                    NaN    NaN
# 4989            ул. Родченко,  2         NaN                    NaN    NaN
#
#       ...  hospital  police  shop  beautySalone  mall  museum  pharmacy  \
# 0     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 1     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 2     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 3     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# ...   ...       ...     ...   ...           ...   ...     ...       ...
# 4985  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4986  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4987  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4988  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4989  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
#
#       sportCenter  postOffice  hotel
# 0             NaN         NaN    NaN
# 1             NaN         NaN    NaN
# 2             NaN         NaN    NaN
# 3             NaN         NaN    NaN
# 4             NaN         NaN    NaN
# ...           ...         ...    ...
# 4985          NaN         NaN    NaN
# 4986          NaN         NaN    NaN
# 4987          NaN         NaN    NaN
# 4988          NaN         NaN    NaN
# 4989          NaN         NaN    NaN
#
# [4990 rows x 23 columns]

# %%
columns_to_check = ['prise', 'rooms', 'square', 'floor', 'totalFloors', 'flat/studio', 'address']

# Фильтрация
index_to_drop = df[df[columns_to_check].isna().any(axis=1)].index

# %%
df = df.drop(index_to_drop)

# %%
display(df)
# Out:
#           prise  rooms  square  floor  totalFloors  flat/studio  \
# 0      650000.0    1.0    35.7      2            6          0.0
# 1     8655450.0    5.0   276.0     24           25          1.0
# 2      745000.0    1.0    15.3     16           24          0.0
# 3     4999000.0    3.0    88.7     24           27          1.0
# 4     4500000.0    4.0   127.0      4           32          1.0
# ...         ...    ...     ...    ...          ...          ...
# 4985  1399000.0    2.0    56.0     12           15          1.0
# 4986  4350000.0    3.0   105.0     10           32          1.0
# 4987  1350000.0    2.0    38.4      2           14          1.0
# 4988   295000.0    1.0    17.7      1            5          0.0
# 4989  1987000.0    1.0    42.0      9           16          1.0
#
#                          address  coordinate  distanceFromTheCenter  metro  \
# 0            Варшавское ш.,  125         NaN                    NaN    NaN
# 1             ул. Лавочкина,  34         NaN                    NaN    NaN
# 2           Ленинский пр-т,  158         NaN                    NaN    NaN
# 3      Шелепихинская наб.,  42к2         NaN                    NaN    NaN
# 4        пр-т Вернадского,  вл78         NaN                    NaN    NaN
# ...                          ...         ...                    ...    ...
# 4985    Скандинавский б-р,  23к2         NaN                    NaN    NaN
# 4986  1-й Нагатинский пр.,  11к2         NaN                    NaN    NaN
# 4987          Озёрная ул.,  29к1         NaN                    NaN    NaN
# 4988      ул. Орджоникидзе,  6/9         NaN                    NaN    NaN
# 4989            ул. Родченко,  2         NaN                    NaN    NaN
#
#       ...  hospital  police  shop  beautySalone  mall  museum  pharmacy  \
# 0     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 1     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 2     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 3     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4     ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# ...   ...       ...     ...   ...           ...   ...     ...       ...
# 4985  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4986  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4987  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4988  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
# 4989  ...       NaN     NaN   NaN           NaN   NaN     NaN       NaN
#
#       sportCenter  postOffice  hotel
# 0             NaN         NaN    NaN
# 1             NaN         NaN    NaN
# 2             NaN         NaN    NaN
# 3             NaN         NaN    NaN
# 4             NaN         NaN    NaN
# ...           ...         ...    ...
# 4985          NaN         NaN    NaN
# 4986          NaN         NaN    NaN
# 4987          NaN         NaN    NaN
# 4988          NaN         NaN    NaN
# 4989          NaN         NaN    NaN
#
# [4916 rows x 23 columns]

# %%
df.to_csv('database.csv', index=False)
